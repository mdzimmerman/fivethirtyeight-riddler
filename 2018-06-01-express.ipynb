# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib
import random

from matplotlib import pyplot as plt
#import seaborn as sns

# %% [markdown]
# ## Jun 1, 2018 - Riddler Express
#
# https://fivethirtyeight.com/features/when-will-your-house-collapse-should-you-take-a-construction-contract

# %%
class Block:
    def __init__(self, size, collapse_order=None):
        self.size=size
        self.houses=np.full(size, 1)
        if collapse_order!=None:
            self.collapse_order=collapse_order
        else:
            self.collapse_order=list(range(size))
            random.shuffle(self.collapse_order)
        self.round=0
        self.states=[]
        self.states.append(list(self.houses))
        
    def isa_neighbor_collapsed(self, i):
        if (i==0):
            return self.houses[i+1]==0
        elif (i==len(self.houses)-1):
            return self.houses[i-1]==0
        else:
            return self.houses[i-1]==0 or self.houses[i+1]==0

    def decay(self):
        while (self.houses == 1).sum() > 0:
            new_collapses=[]
            for i in range(self.size):
                if self.houses[i]==1 and self.isa_neighbor_collapsed(i):
                    new_collapses.append(i)
            for j in new_collapses:
                self.houses[j]=0
            self.houses[self.collapse_order[self.round]]=0
            self.states.append(list(self.houses))
            self.round+=1
            
    def print_state(self):
        for s in self.states:
            print("".join([str(x) for x in s]))
    
results=[]
for i in range(1000):
    b=Block(36)
    b.decay()
    #if (b.round>=20):
        #b.print_state()
        #print()
    results.append(b.round)
plt.hist(results,bins=list(range(30)))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
c1=list(range(36))
b1=Block(36, collapse_order=c1)
b1.decay()
b1.print_state()
print(b1.round)
# Out:
# 111111111111111111111111111111111111
# 011111111111111111111111111111111111
# 001111111111111111111111111111111111
# 000111111111111111111111111111111111
# 000011111111111111111111111111111111
# 000001111111111111111111111111111111
# 000000111111111111111111111111111111
# 000000011111111111111111111111111111
# 000000001111111111111111111111111111
# 000000000111111111111111111111111111
# 000000000011111111111111111111111111
# 000000000001111111111111111111111111
# 000000000000111111111111111111111111
# 000000000000011111111111111111111111
# 000000000000001111111111111111111111
# 000000000000000111111111111111111111
# 000000000000000011111111111111111111
# 000000000000000001111111111111111111
# 000000000000000000111111111111111111
# 000000000000000000011111111111111111
# 000000000000000000001111111111111111
# 000000000000000000000111111111111111
# 000000000000000000000011111111111111
# 000000000000000000000001111111111111
# 000000000000000000000000111111111111
# ...

# %%
c2=[17,27,3,9,33,35]
b2=Block(36, collapse_order=c2)
b2.decay()
b2.print_state()
print(b2.round)
# Out:
# 111111111111111111111111111111111111
# 111111111111111110111111111111111111
# 111111111111111100011111111011111111
# 111011111111111000001111110001111111
# 110001111011110000000111100000111111
# 100000110001100000000011000000011011
# 000000000000000000000000000000000000
# 6

# %%
import copy

class Node:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __eq__(self, other):
        if isinstance(other, Node):
            return self.x == other.x and self.y == other.y
        return NotImplemented
    
    def __hash__(self):
        return hash(tuple(sorted(self.__dict__.items())))
    
class GridGraph:
    def __init__(self, w, h):
        self.width  = w
        self.height = h
        self.nodes = set()
        
        for i in range(w):
            for j in range(h):
                self.nodes.add(Node(i, j))
        
    def nodesCopy(self):
        return copy.copy(self.nodes)
        
    def neighbors(self, n):
        out = set()
        if n.x > 0:
            out.add(Node(n.x-1, n.y))
        if n.x < self.width-1:
            out.add(Node(n.x+1, n.y))
        if n.y > 0:
            out.add(Node(n.x, n.y-1))
        if n.y < self.height-1:
            out.add(Node(n.x, n.y+1))
        return out
        
    def weight(self, n1, n2):
        if n1.x == w and n2.x == w:
            return 0.1
        else:
            return 1.0

def dijkstra(graph, start):
    vertices = graph.nodesCopy()
    dist = dict()
    previous = dict()
    
    for v in vertices:
        dist[v] = float("inf")
        previous[vertex] = None
        
    dist[start] = 0
    Q = set(vertices)
    
    while len(Q)
    
        
grid = GridGraph(21,61)
